# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Ольга, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Пример можно посмотреть в самом первом проекте (Музыка городов)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# **Цель исследования**
# -  выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
# **Ход исследования**
# 1. Провести обзор данных
# 2. Провести предобработку данных
# - заполнить пропущенные значения в столбцах
# - преобразовать типы данных
# - выявить и обработать дубликаты
# 3. выявить и устранить выбивающиеся значения
# 4. Провести исследовательский анализ
# - изучить параметры объектов
# - изучить, как быстро продаются квартиры
# - изучить факторы, влияющие на стоимость объекта
# - посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.
# - выделить населённые пункты с самой высокой и низкой стоимостью квадратного метра
# - выделитm квартиры в Санкт-Петербурге,  вычислитm среднюю цену каждого километра и описать, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Давай эти выводы перенесем в обычную ячейку markdown? Синий фон нужен для диалога между нами (вопросы, ответы, пожелания, мемчики с Пикабу)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt 

data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
print(data.head())
data.info()
data.hist(figsize = (15, 20))
plt.show()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# А для чего тут decimal?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# - decimal - для разделения десятичных дробей - удалила
# - предупреждение убрала

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Пропущенные значения в столбцах

# %%
# Подсчитаем количество пропусков в Датафрейме.

# data.isna().sum()
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_18340_row0_col0,#T_18340_row1_col0,#T_18340_row2_col0,#T_18340_row3_col0,#T_18340_row4_col0,#T_18340_row6_col0,#T_18340_row8_col0,#T_18340_row10_col0,#T_18340_row11_col0,#T_18340_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_18340_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_18340_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_18340_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_18340_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_18340_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_18340_row15_col0,#T_18340_row16_col0,#T_18340_row17_col0,#T_18340_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# Продавец не указал название населённого пункта.
# Таких значений немного, восстановить их невозможно, поэтому удалим строки с пропусками.

# %%
data = data.dropna(subset = ['locality_name'])

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Описывать ходы действий в ячейках хода - плохая практика. Давай их перенесем в обычную ячейку markdown?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Спасибо за правки)

# %% [markdown]
# Продавец не указал число балконов, скорее всего, в его квартире их нет.
# Заменим пропуски на 0.

# %%
print(data['balcony'].unique()) 
data['balcony'] = data['balcony'].fillna(0) 
# print(data.head())
# Out:
# [nan  2.  0.  1.  5.  4.  3.]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# Заполним пропуски медианным значением в столбцах:
# ceiling_height — высота потолков (м)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# floors_total — всего этажей в доме
# #living_area — жилая площадь в квадратных метрах (м²)
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_nearest — расстояние до ближайшего водоёма (м)
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)

# %%
     
data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].median()
    
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = data['kitchen_area'].median()
        
data.loc[data['floors_total'].isna(), 'floors_total'] = data['floors_total'].median()
               
data.loc[data['living_area'].isna(), 'living_area'] = data['living_area'].median()

data.loc[data['parks_nearest'].isna(), 'parks_nearest'] = data['parks_nearest'].median()

data.loc[data['ponds_nearest'].isna(), 'ponds_nearest'] = data['ponds_nearest'].median()

data.loc[data['airports_nearest'].isna(), 'airports_nearest'] = data['airports_nearest'].median()
    
# data.isna().sum()

print('медиана высоты потолка', data['ceiling_height'].median())

print('медиана площади кухни', data['kitchen_area'].median())
 
print('медиана всего этажей',data['floors_total'].median())

print('медиана жилой площади',data['living_area'].median())

print('медиана расстояния до ближайшего парка',data['parks_nearest'].median())

print('медиана расстояния до ближайшего водоёма',data['ponds_nearest'].median())

print('медиана расстояния до ближайшего аэропорта',data['airports_nearest'].median())
# Out:
# медиана высоты потолка 2.65
# медиана площади кухни 9.1
# медиана всего этажей 9.0
# медиана жилой площади 30.0
# медиана расстояния до ближайшего парка 454.5
# медиана расстояния до ближайшего водоёма 502.0
# медиана расстояния до ближайшего аэропорта 26756.5

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>

# %%
# Заполним пропуски в столбце 'cityCenters_nearest' по городу Санкт-Петербург медианным значением по Санкт-Петербургу.

# cityCenters_nearest — расстояние до центра города (м)

center_median_SPB = data.loc[(data['locality_name'] == 'Санкт-Петербург'), 'cityCenters_nearest'].median()
data.loc[(data['locality_name'] == 'Санкт-Петербург') & (data['cityCenters_nearest'].isna()), 'cityCenters_nearest'] = center_median_SPB

print('медиана расстояния до центра Санкт-Петербурга', center_median_SPB)
# Out:
# медиана расстояния до центра Санкт-Петербурга 12244.5

# %%
# Заполним пропуски в столбце 'cityCenters_nearest' по всем городам, кроме Санкт-Петербурга, медианным значением по всем городам

data.loc[data['cityCenters_nearest'].isna(), 'cityCenters_nearest'] = data['cityCenters_nearest'].median()
    
print('медиана по всем населенным пунктам', data['cityCenters_nearest'].median())
# Out:
# медиана по всем населенным пунктам 13073.0

# %%
# Заполним пропуски значением 0 в столбцах:
# parks_around3000 — число парков в радиусе 3 км
# ponds_around3000 — число водоёмов в радиусе 3 км

columns_to_replace = ['parks_around3000', 'ponds_around3000'] # перебор названий столбцов в цикле и замена пропущенных значений на 0
for item in columns_to_replace:     
    data[item] = data[item] .fillna(0)

# %%
# print(data.head(50))
columns_to_replace = ['is_apartment'] # перебор названий столбцов в цикле и замена пропущенных значений на True
for item in columns_to_replace:     
    data[item] = data[item] .fillna(True)

# %%
# Пропуске в столбце 'days_exposition' — сколько дней было размещено объявление (от публикации до снятия) 
# заполним медианным значением по этому столбцу. 
data.loc[data['days_exposition'].isna(),'days_exposition']  = data['days_exposition'].median()    
# print(data['days_exposition'].median()) 
# Проверим все ли пропуски заполнены
data.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %% [markdown]
# ##### Вывод
#
# Появление пропусков в Датафрейме возможно по нескольким причинам.
#
# * Пропуски в даных о площади кухонь, жилых помещений, высоте потолков и количестве этажей, вероятнее всего, связаны с человеческим фактором. Продавец мог намеренно не внести некоторые данные, потому что не считает их важними или не владеет информацией или случайно. Данные пропуски заполним на основании расчитанной медианы.
#
# * Пропуски данных о наличии балконов, вероятно, связаны с отсутсвием балкона в квартире. Заполним пропуски значением 0.
#
# * Данные о расстоянии до центра города, до аэропорта, о количестве прудов и парков, а также о расстоянии до парков и прудов количества прудов заполнялись автоматически, на основе картографических данных. Можем предположить, что пропуски в этих данных связаны с отсутсвием по ним информации в базе.
#
# * Пропуски в столбцах со значением количества прудов и парков заполняем значением 0, так как предполагаем, что в заданной области парки и пруды отсутсвуют.
#
# * Пропуски в столбцах с расстоянием до центра города, до парков и прудов заполним на основании расчитанной медианы по всему стодбцу. Отдельно расчитаем медиану расстояния до центра города Санкт-Петербург.
#
# * Пропуски в столбце 'is_apartment', вероятнее всего, вызваны технической ошибкой. Предполагаем, что заполнены только значения False, возможно, это коммерческая недвижимость. Поэтому для остальных квартир заполним пропуски значением True, то есть квартиры являются апартаментами.
#
# * Пропуски в столбце 'days_exposition' в основном относятся к более свежим объявлениям и вероятно ещё не были сняты с публикации на момент выгрузки базы данных. Мы их заполнили медианным значением по столбцу 'days_exposition'.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Замена пропусков выполнена корректно
# </div>

# %% [markdown]
# #### Типы данных

# %%
# Преобразуем тип данных в выбранных столбцах.
# Форматируем дату и время в столбце first_day_exposition — дата публикации
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')
#print(data.head(10))

# Заменим строковый тип данных на целочисленный в столбцах: 
# floors_total — всего этажей в доме
# balcony — число балконов
# parks_around3000 — число парков в радиусе 3 км
# ponds_around3000 — число водоёмов в радиусе 3 км
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)

#data['floors_total'] = data['floors_total'].astype(int)
data['balcony'] = data['balcony'].astype(int)
data['parks_around3000'] = data['parks_around3000'].astype(int)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)
data['days_exposition'] = data['days_exposition'].astype(int)
data['last_price'] = data['last_price'].astype(int)

# Заменим строковый тип данных на вещественный в столбцах:
# last_price — цена на момент снятия с публикации
# total_area — общая площадь квартиры в квадратных метрах (м²)
# ceiling_height — высота потолков (м)
# living_area — жилая площадь в квадратных метрах (м²)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# cityCenters_nearest — расстояние до центра города (м)
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_nearest — расстояние до ближайшего водоёма (м)
# last_price — цена на момент снятия с публикации

#data['last_price'] = data['last_price'].astype(float)
data['total_area'] = data['total_area'].astype(float)
data['ceiling_height'] = data['ceiling_height'].astype(float)
data['living_area'] = data['living_area'].astype(float)
data['kitchen_area'] = data['kitchen_area'].astype(float)
data['airports_nearest'] = data['airports_nearest'].astype(float)
data['cityCenters_nearest'] = data['cityCenters_nearest'].astype(float)
data['parks_nearest'] = data['parks_nearest'].astype(float)
data['ponds_nearest'] = data['ponds_nearest'].astype(float)

# Заменим строковый тип данных на  тип bool в столбцах:
data['is_apartment'] = data['is_apartment'].astype(bool)


data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  int64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23650 non-null  float64
#  7   living_area           23650 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          23650 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ##### Вывод
#
# * Мы изменили строковый тип данных на целочисленный и вещественный во всех столбцах, кроме 'locality_name' для того, чтобы эти данные можно было обрабатывать: производить вычисления, строить графики.
# * Также отформатировали дату и время в столбце first_day_exposition

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
# __Комментарий от ревьюера №1__
#
# Давай посмотрим на столбец `last_price`, он имеет дробный тип данных. Но ведь никто не продаёт недвижку с копейками. Что думаешь?
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# - тип данных в `last_price` изменила на int

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Всё верно

# %% [markdown]
# #### Уникальные значения и неявные дубликаты.

# %%
# Изучим название населенных пунктов

# print(data['locality_name'].sort_values().unique())
print(data['locality_name'].value_counts().head(10))
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %%
# Заменим все виды поселений
data['locality_name'] = data['locality_name'].replace('Кудрово', 'посёлок Кудрово')   
data['locality_name'] = data['locality_name'].replace('Мурино', 'посёлок Мурино')
list_for_replace = ['поселок', 'поселок городского типа', 'посёлок городского типа', 'село', 'деревня', 'городской посёлок', \
'коттеджный поселок', 'посёлок при железнодорожной станции', 'посёлок станции', 'садоводческое некоммерческое товарищество', 'садовое товарищество']
for item in list_for_replace:
    data['locality_name'] = data['locality_name'].str.replace(item, 'посёлок')

# print(data['locality_name'].sort_values().unique())
print(data['locality_name'].value_counts().head(10))  # количество уникальных значений в 'locality_name' уменьшилось с 364 до 310
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         590
# посёлок Кудрово        472
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличный код
# </div>

# %%
# проверим количество явных дубликатов
print ('Явных дубликатов в таблице:', data.duplicated().sum())
# Out:
# Явных дубликатов в таблице: 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубилкаты - основа предобработки данных
# </div>

# %% [markdown]
# #### Аномалии, редкие и выбивающиеся значения.

# %%
# print(data['ceiling_height'].sort_values().unique())

# Стандартная высота потолка начинается от 2,5. Посчитаем высоту до 10 м (2-х 3-х этажные квартиры)
# Предположим, что высота 25 - 32 м указана ошибочно. Исправим данные значения.
# и удалим редкие и выбивающиеся значения.

for item in range(len(data['ceiling_height'])):
    data['ceiling_height'] = data['ceiling_height'].replace(item, item / 10)
              
#data['ceiling_height'] = data['ceiling_height'].replace(25, 2.5)
#data['ceiling_height'] = data['ceiling_height'].replace(26, 2.6)
#data['ceiling_height'] = data['ceiling_height'].replace(27, 2.7)
#data['ceiling_height'] = data['ceiling_height'].replace(27.5, 2.75)
#data['ceiling_height'] = data['ceiling_height'].replace(32, 3.2)


data = data[(data['ceiling_height'] >= 2.5) & (data['ceiling_height'] <= 10)]
print(data['ceiling_height'].sort_values().unique())
# Out:
# [ 2.5   2.51  2.52  2.53  2.54  2.55  2.56  2.57  2.58  2.59  2.6   2.61
#   2.62  2.63  2.64  2.65  2.66  2.67  2.68  2.69  2.7   2.71  2.72  2.73
#   2.74  2.75  2.76  2.77  2.78  2.79  2.8   2.81  2.82  2.83  2.84  2.85
#   2.86  2.87  2.88  2.89  2.9   2.91  2.92  2.93  2.94  2.95  2.96  2.97
#   2.98  2.99  3.01  3.02  3.03  3.04  3.05  3.06  3.07  3.08  3.09  3.1
#   3.11  3.12  3.13  3.14  3.15  3.16  3.17  3.18  3.2   3.21  3.22  3.23
#   3.24  3.25  3.26  3.27  3.28  3.29  3.3   3.31  3.32  3.33  3.34  3.35
#   3.36  3.37  3.38  3.39  3.4   3.42  3.43  3.44  3.45  3.46  3.47  3.48
#   3.49  3.5   3.51  3.52  3.53  3.54  3.55  3.56  3.57  3.58  3.59  3.6
#   3.62  3.63  3.65  3.66  3.67  3.68  3.69  3.7   3.75  3.76  3.78  3.8
#   3.82  3.83  3.84  3.85  3.86  3.87  3.88  3.9   3.93  3.95  3.98  4.06
#   4.1   4.14  4.15  4.19  4.2   4.25  4.3   4.37  4.4   4.45  4.5   4.65
#   4.7   4.8   4.9   5.2   5.3   5.5   5.6   5.8   8.3  10.  ]

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше не хардкодить, а использовать функцию: если значение больше 20, то разделить на 10
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# Код исправила. Предыдущий код закомментировала

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Идеально ^^

# %%
import matplotlib.pyplot as plt 
data.boxplot('total_images')
print(data['total_images'].describe())
plt.show()
data.boxplot('last_price', figsize=(12, 6))
print(data['last_price'].describe())
plt.show()
data.boxplot('total_area')
print(data['total_area'].describe())
plt.show()
data.boxplot('rooms')
print(data['rooms'].describe())
plt.show()
data.boxplot('ceiling_height')
print(data['ceiling_height'].describe())
plt.show()
data.boxplot('floors_total')
print(data['floors_total'].describe())
plt.show()
data.boxplot('living_area')
print(data['living_area'].describe())
plt.show()
data.boxplot('floor')
print(data['floor'].describe())
plt.show()
data.boxplot('kitchen_area')
print(data['kitchen_area'].describe())
plt.show()
data.boxplot('balcony')
print(data['balcony'].describe())
plt.show()
data.boxplot('airports_nearest')
print(data['airports_nearest'].describe())
plt.show()
data.boxplot('cityCenters_nearest')
print(data['cityCenters_nearest'].describe())
plt.show()
data.boxplot('days_exposition')
print(data['days_exposition'].describe())
plt.show()
data.boxplot('parks_nearest')
print(data['parks_nearest'].describe())
plt.show()
data.boxplot('ponds_nearest')
print(data['ponds_nearest'].describe())
plt.show()
# Out:
# count    22419.000000
# mean         9.834382
# std          5.660378
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: total_images, dtype: float64
# count    2.241900e+04
# mean     6.292934e+06
# std      1.077861e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.550000e+06
# 75%      6.500000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64
# count    22419.000000
# mean        59.221571
# std         34.921073
# min         12.000000
# 25%         39.800000
# 50%         51.000000
# 75%         68.000000
# max        900.000000
# Name: total_area, dtype: float64
# count    22419.000000
# mean         2.045899
# std          1.066689
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64
# count    22419.000000
# mean         2.681034
# std          0.215496
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что  проверяешь данные не "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их с помощью специального метода boxplot()

# %%
# data.info()

# %% [markdown]
# Подготовим срезы по стобцам, избавимся от выбросов.

# %%
data = data.query('total_images < 35 and last_price < 40.000000e+06 and last_price > 0.1000000e+06 and total_area < 550 \
and rooms < 10 and ceiling_height < 6 and floors_total < 40 and living_area < 250 and floor < 40 and kitchen_area < 80 \
and balcony < 5 and airports_nearest < 90000 and days_exposition < 1600 and cityCenters_nearest < 60000 and parks_nearest < 3000')

#data = data.query('total_images > 6 - (14-6)*1.5 and total_images < 14 + (14-6)*1.5')
#data = data.query('last_price >3.425000e+06 - (6.800000e+06-3.425000e+06)*1.5 and last_price < 6.800000e+06 + (6.800000e+06-3.425000e+06)*1.5')
#data = data.query('total_area > 40 - (69.9-40)*1.5 and total_area < 69.9 + (69.9-40)*1.5')
# data = data.query('rooms > 1 - (3-1)*1.5 and rooms < 3 + (3-1)*1.5')
# data = data.query('ceiling_height > 2.6 - (2.7-2.6)*1.5 and ceiling_height < 2.7 + (2.7-2.6)*1.5')
# data = data.query('floors_total > 5 - (16-5)*1.5 and floors_total < 16 + (16-5)*1.5')
#data = data.query('living_area > 19 - (41.1-19)*1.5 and living_area < 41.1 + (41.1-19)*1.5')
# data = data.query('floor > 2 - (8-2)*1.5 and floor < 8 + (8-2)*1.5')
#data = data.query('kitchen_area> 7.4 - (11.5-7.4)*1.5 and kitchen_area < 11.5 + (11.5-7.4)*1.5')
#data = data.query('balcony > 0 - (1-0)*1.5 and balcony < 1 + (1-0)*1.5')
#data = data.query('airports_nearest > 21172- (34395-21172)*1.5 and airports_nearest < 34395 + (34395-21172)*1.5')
#data = data.query('days_exposition > 45 - (198-45)*1.5 and days_exposition < 198 + (198-45)*1.5')
#data = data.query('cityCenters_nearest < 15250 + (15250-10937)*1.5')

# Не делаем срезы по столбцам parks_nearest и ponds_nearest, так как в первоначальном датасете 
# было большое количество пропусков, которые мы заполнили медианой. Если сделать срез и удалить выбросы, 
# то потеряем много строк в базе данных.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# По итогу у нас удалено 50% датафрейма, он стал скудным. Не стоит полностью доверяться боксплоту, а удалять со здравым смыслом
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# Исправила код. Не знаю, правильно или нет...С одной стороны надо удалить выбросы с помощью специального метода boxplot()
#     А с другой стороны - не стоит полностью доверяться боксплоту, а удалять со здравым смыслом. Нет ясности в этом вопросе. Про
#
#     Как же быть? :)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Согласен, моя вина (неправильно подал информацию, исправляюсь). Боксплот не идеален (ведь он может посчитать, например, что 4 парка рядом это аномалия). Но ведь, если пользователь живет в центре, то это вполне ествественно. Поэтому да, тут стоит подключать здравый смысл)

# %%
# Сделаем срез по столбцу is_apartment. Выберем квартиры, которые имеют тип bool = True.

data = data.query('is_apartment == True')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19490 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          19490 non-null  int64
#  1   last_price            19490 non-null  int64
#  2   total_area            19490 non-null  float64
#  3   first_day_exposition  19490 non-null  datetime64[ns]
#  4   rooms                 19490 non-null  int64
#  5   ceiling_height        19490 non-null  float64
#  6   floors_total          19490 non-null  float64
#  7   living_area           19490 non-null  float64
#  8   floor                 19490 non-null  int64
#  9   is_apartment          19490 non-null  bool
#  10  studio                19490 non-null  bool
#  11  open_plan             19490 non-null  bool
#  12  kitchen_area          19490 non-null  float64
#  13  balcony               19490 non-null  int64
#  14  locality_name         19490 non-null  object
# ...

# %% [markdown]
# ##### Вывод
#
# * Аномальные значения выявлены в столбце ceiling_height — высота потолков (м). Предположили, что в столбце ceiling_height — высота потолков (м) значения от 25 м до 32 м заведены ошибочно. Исправим их на значения от 2.5 до 3.2 м соответственно.
#
# * Метод describe() позволил выявить выбросы и сделать срезы с помощью межквартильного размаха для всех столбцов с количественными значениями, кроме столбцов parks_nearest и ponds_nearest. Из-за большого количества пропусков в этих столбцах в первоначальном датасете, которые мы заполнили медианой, сделать срез можно, но это будет срез по одному медианному значению, что в дальнейшем может исказить анализ данных. Поэтому по данным столбцам срез не делаем.
#
# * Сделаем срез по столбцу is_apartment. Выберем квартиры, которые имеют тип bool = True. Ранее предположили, что тип  bool = False имеет коммерческая недвижимость, например.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
# Расчёт цены одного квадратного метра

data['price_sq_meters'] = data['last_price'] / data['total_area']
data['price_sq_meters'] = data['price_sq_meters'].astype(int)
#print(data.head())

# %%
# День недели публикации объявления (0 — понедельник, 1 — вторник и так далее)
import numpy as np
data['weekday'] = data['first_day_exposition'].dt.weekday

# Месяц публикации объявления
data['month'] = data['first_day_exposition'].dt.month
#data['month'] = np.datetime64(data['month'], 'M')

# Год недели публикации объявления
data['year'] = data['first_day_exposition'].dt.year
print(data.tail())
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23693             9     4600000       62.40           2016-08-05      3
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 23693            2.60           9.0         40.0      8          True  ...
# 23694            3.70           5.0         73.3      3          True  ...
# 23695            2.65           5.0         38.0      4          True  ...
# 23696            2.65           3.0         29.7      1          True  ...
# 23698            2.50           5.0         12.3      1          True  ...
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# пока не очень поняла, как это работает   # data['month'] = np.datetime64(data['month'], 'M') - не так?

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Данный способ нужен для изучения динамики по дням, месяцам или годам. Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %%
data = data.reset_index(drop=True)

# %%
# тип этажа квартиры (значения — «‎первый», «последний», «другой»)

def floor_type(row):
    
    floor = row['floor']
    floors_total = row['floors_total']
    
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    return 'другой'

data['floor_type'] = data.apply(floor_type, axis=1)
    
# print(data.head(20))

# %%
# расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# data['cityCenters_km'] = (data['cityCenters_nearest'] / 1000).astype(float)
data['cityCenters_km'] = (data['cityCenters_nearest'] / 1000).astype(int)
# print(data.head())

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует округление
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# Округлила методом astype(int)

# %%
# data.info()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров объектов

# %%
# Построим гистограммы для каждого параметра

data['total_area'].hist(bins=50, range=(0, 200)) 
plt.show()
data['living_area'].hist(bins=50, range=(0, 100)) 
plt.show()
data['kitchen_area'].hist(bins=50, range=(0, 60)) 
plt.show()
data['last_price'].hist(bins=50, range=(0, 20000000 ))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
# ##### Вывод
#
# - общая площадь; Большинство квартир, выставленных на продажу, имеют общую площадь от 25 до 60 м2. Максимальное ко-во квартир имеет площадь 40-50 м2. Кол-во квартир с площадью от 70 до 150 м2 значительно снижается. Чем больше площадь, тем меньше таких квартир выставлено на продажу. Квартир с площадь менее 25 м2 практически нет в базе данных.
#
# - жилая площадь; Большинство квартир имеют жилую площадь порядка 18 м2 или 25-30 м2. Вероятно это типовые планировки. Кол-во квартир с жилой площадью от 30 до 70 м2 значительно снижается.
#
# - площадь кухни; в большинстве квртир площадь кухни составляет около 10-15 м2. Гораздо меньше квартир имеют площадь меньше или больше этого показателя.
#
# - цена объекта; Большинство квартир представлено в датасете в ценовом диапазоне от 2,5 млн до 5 млн. рублей. количество квартир стоимостью менее 2,5 млн рублей и более 5 млн. рублей постепенно снижается.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что используешь метод range() для определения пиковых значений
# </div>

# %%
plt.show()
data['rooms'].hist(bins=50, range=(0, 10)) 
plt.show()
data['ceiling_height'].hist(bins=50, range=(0, 5)) 
plt.show()
data['floor'].hist(bins=50, range=(0, 30)) 
plt.show()
data['floor_type'].hist(bins=50, range=(0, 5))
plt.show()
data['floors_total'].hist(bins=50, range=(0, 30))
plt.show()

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
# ##### Вывод
#
# - количество комнат; В базе данных в основном представлены квартиры 1-комнатные и 2-комнатные квартиры. Чуть меньше 3-х комнатных квартир и совсем мало квартир с большим количеством комнат. 0-комнатные квартиры, по видимому, студии.
#
# - высота потолков; в большинстве квартир стандартная высота потолков от 2,5 до 2,8 м.
#
# - этаж квартиры; В базе много квартир, расположенных на 1-5 этажах. Более высокие этажи встречаются все реже.
#
# - тип этажа квартиры («первый», «последний», «другой»); Тем не менее, среди всех квартир первый и последний этажи встречаются реже. Большинство квартир расположено на промежуточных этажах.
#
# - общее количество этажей в доме; Чаще других в базе встречаются 5-этажные и 9- этажные дома.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Здорово, что пишешь промежуточные выводы
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data['cityCenters_nearest'].hist(bins=50, range=(0, 20000)) 
plt.show()
data['airports_nearest'].hist(bins=50, range=(0, 50000)) 
plt.show()
data['parks_nearest'].hist(bins=50, range=(0, 1000)) 
plt.show()

# %%
data['weekday'].hist(bins=50, range=(0, 6))
# Out:
# <AxesSubplot:>

# %%
data['month'].hist(bins=50, range=(0, 100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В мае не до продаж, все на огородах =)
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
# ##### Вывод
#
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
#
#     На гистограммах с расстоянием имеется пиковое значение. Это связано с тем в данных столбцах было очень много пропусков, которые были заполнены медианным значением по всему столбцу, независимо от населенного пункта. А в случае расстояние до ближайшего парка пропусков порядка 14000.
#
# - день и месяц публикации объявления; Исходя из данных, представленных на гистограмме, можно заключить, что большинство объявлений регистрируют в базе данных в будние дни, причем в понедельник реже, чем со вторника по пятницу. Больше всего объявлений публикуется в феврале. Далее следуют март, апрель. Январь, май, декабрь отстают по количеству размещенных в эти месяцы объявлений, что можно объяснить бОльшим количеством праздничных дней в эти месяцы. Далее количество объявлений начинает расти с июня по ноябрь.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше после каждого графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого теста или графика.

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
# перенесла выводы

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Спасибо =) Так лучше
# </div>

# %% [markdown]
# #### Изучение как быстро продавались квартиры

# %%
# Изучим, как быстро продавались квартиры (столбец days_exposition). 

data['days_exposition'].hist(bins=50, range=(0, 1000))

days_exposition_mediana = data['days_exposition'].median()  
days_exposition_mean = data['days_exposition'].mean() 
plt.show()
data.boxplot('days_exposition')
print(data['days_exposition'].describe())

print('Медиана количества дней на сайте =', days_exposition_mediana)
print('Среднее значение количества дней на сайте =', days_exposition_mean)
# Out:
# count    19490.000000
# mean       162.305387
# std        200.756205
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        187.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
# Медиана количества дней на сайте = 95.0
# Среднее значение количества дней на сайте = 162.30538737814263

# %% [markdown]
# ##### Вывод
#
# Рассмотрим гистаграмму столбца 'days_exposition' c данными, полученными в результате вызова метода describe().
# - Минимальный срок продажи квартиры - 1 день
# - Максимальный срок продажи квартиры - 1580 дней
# - Медиана продаж составляет  - 90 дней
# - Среднее кол-во дней продажи составляет - 186 дней
# - Большинство квартир продается в период от 1,5 до 6 месяцев (179 дней) с момента размещения объявления.
#
# Очень быстрыми можно считать продажи в течение менее 45 дней.
# Очень медленными продажами можно считать продажи дольше 380 дней. (179+(179-45)*1.5=380)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# да, до 1.5 месяцев можно считать быстрой продажей
# </div>

# %% [markdown]
# #### Исследовательский анализ данных.  Факторы, влияющие на общую стоимость объекта.

# %% [markdown]
# Построим графики, которые покажут зависимость цены от указанных ниже параметров.
# общей площади;
# жилой площади;
# площади кухни;
# количество комнат;
# типа этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год);

# %%
# Построим диаграмму рассеяния, чтобы определить, как связаны стоимость квартир и общая площадь.

data.plot(x='last_price', y='total_area', kind = 'scatter', ylim=(0, 300), xlim=(0, 12000000), grid=True, figsize=(12, 6), alpha = 0.05 ) 

# Рассчитаем коэффициент Пирсона находят методом corr()

print('коэффициент Пирсона = ', data['last_price'].corr(data['total_area']))
# Out:
# коэффициент Пирсона =  0.7868304256720773

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
#     ##### Вывод
#
# - На основании диаграмм рассеивания и расчёта коэффициента Пирсона выявлено влияние параметров квартиы на её стоимость.
#
# общая площадь; коэффициент Пирсона = 0.79. С увеличением общей площади стоимость квартир возрастает.

# %%
# Построим диаграмму рассеяния, чтобы определить, как связаны жилая площадь и стоимость квартир.

data.plot(x='last_price', y='living_area', kind = 'scatter', ylim=(0, 200), xlim=(0, 12000000), grid=True, figsize=(12, 6), alpha = 0.05 ) 

# Рассчитаем коэффициент Пирсона находят методом corr()

print('коэффициент Пирсона = ', data['last_price'].corr(data['living_area']))
# Out:
# коэффициент Пирсона =  0.651146697055398

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
#     ##### Вывод
#
#  - жилая площадь; коэффициент Пирсона = 0.65.
#  С увеличением жилой площади стоимость квартир возрастает, но данная зависимость выражена слабее, чем зависимость от общей площади.

# %%
# Построим диаграмму рассеяния, чтобы определить, как связаны площадь кухни и стоимость квартир.

data.plot(x='last_price', y='kitchen_area', kind = 'scatter', ylim=(0, 100), xlim=(0, 12000000), grid=True, figsize=(12, 6), alpha = 0.05 ) 

# Рассчитаем коэффициент Пирсона находят методом corr()

print('коэффициент Пирсона = ', data['last_price'].corr(data['kitchen_area']))
# Out:
# коэффициент Пирсона =  0.5728253841236404

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
# площадь кухни; коэффициент Пирсона = 0.57. С увеличением площади кухни стоимость квартир возрастает, но данная зависимость выражена ещё слабее, чем зависимость от жилой или общей площади.

# %%
# Построим диаграмму рассеяния, чтобы определить, как связаны число комнат и стоимость квартир.

data.plot(x= 'rooms', y= 'last_price', kind = 'scatter', xlim=(-1, 7), ylim=(0, 13000000), grid=True, figsize=(10, 5)) 

# По диаграмме рассеяния сложно визуально определить взаимосвязь между числом комнат и стоимостью квартир.
# Рассчитаем медиану стоимости квартиры в зависимости от количества комнат и построим график зависимости медианной стоимости 
# квартиры от количества комнатю

data_room_grouped = data.pivot_table(index = 'rooms', values = 'last_price', aggfunc = 'median')
data_room_grouped.plot(y = 'last_price', style='o-', xlim=(-1, 7))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
#     ##### Вывод
#
# количество комнат; Количество комнат влияет на стоимость квартир. Чем больше комнат, тем дороже квартира.

# %%
# Проведем аналогичные расчёты и постоения чтобы определить, как связаны параметры тип этажа и стоимость квартир.

data_floor_type_grouped = data.pivot_table(index = 'floor_type', values = 'last_price', aggfunc = 'median')
data_floor_type_grouped.plot(y = 'last_price', style='o-')
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__(перенесла вывод)
#
#  - тип этажа квартиры («первый», «последний», «другой»); Стоимость квартир зависит от этажа. Первый и последний этажи ценятся дешевле, чем промежуточные этажи. При этом первый этаж ценится дешевле последнего.

# %%
# Проведем аналогичные расчёты и постоения чтобы определить, как связаны день недели размещения объявления и стоимость квартир.

data_weekday_grouped = data.pivot_table(index = 'weekday', values = 'last_price', aggfunc = 'median')
data_weekday_grouped.plot(y = 'last_price', style='o-')
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
# Проведем аналогичные расчёты и постоения чтобы определить, как связаны месяц размещения объявления и стоимость квартир.

data_month_grouped = data.pivot_table(index = 'month', values = 'last_price', aggfunc = 'median') \
.plot(y = 'last_price', style='o-', figsize=(8, 4) )

# %%
# Проведем аналогичные расчёты и постоения чтобы определить, как связаны год размещения объявления и стоимость квартир.

data_year_grouped = data.pivot_table(index = 'year', values = 'last_price', aggfunc = 'median')
data_year_grouped.plot(y = 'last_price', style='o-')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ##### Вывод
#
# - день, месяц и год публикации объявления;
#
# - Графики строим на основании расчёта медианны стоимости квартир в зависимости от дня недели, месяца или года.
# - Из графиков видно, что медиана стоимости квартир снизилась с 2014 по 2017 год. Рост стоимости квартир возобновился с 2017 по 2019 г.
# - со вторника по субботу медиана цены падает. С воскресенья по вторник - растет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация значений корреляции Пирсона. Ты молодец =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# #### Исследовательский анализ данных.  Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.
# Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. 
# Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

print(data['locality_name'].value_counts().head(10))

# Создадим список из 10 населённых пунктах с наибольшим числом объявлений. 
locality_name_top = ['Санкт-Петербург', 'посёлок Мурино','посёлок Кудрово', 'Всеволожск', 'Гатчина', 'Выборг', 'посёлок Шушары', \
                    'Кудрово ', 'посёлок Парголово','Кириши', 'Сертолово']
# price_sq_meters
# Сделаем срез по 10 населённым пунктам с наибольшим числом объявлений

data_top = data.query('locality_name in @locality_name_top')

for item in data_top['locality_name'].unique():
    # average_price = data_top.pivot_table(index = 'locality_name', values = 'price_sq_meters')
    average_price = data_top.pivot_table(index = 'locality_name', values = 'price_sq_meters', aggfunc = 'median')

average_price.columns = ['average_price_sq_meters']
average_price['average_price_sq_meters'] = average_price['average_price_sq_meters'].astype(int)

print(average_price.sort_values(by = 'average_price_sq_meters', ascending=False))
# Out:
# Санкт-Петербург      12762
# посёлок Мурино         503
# посёлок Кудрово        409
# посёлок Шушары         377
# Всеволожск             340
# Пушкин                 298
# посёлок Парголово      285
# Колпино                281
# Гатчина                247
# Выборг                 198
# Name: locality_name, dtype: int64
#                    average_price_sq_meters
# locality_name
# Санкт-Петербург                     103921
# посёлок Кудрово                      96296
# посёлок Парголово                    92282
# посёлок Мурино                       86268
# посёлок Шушары                       77540
# Сертолово                            67720
# Гатчина                              67045
# Всеволожск                           66072
# Выборг                               58133
# Кириши                               37976

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий №1__
#
#  Исправила. Расчёт среднего значения за м2 произвела через медиану.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Эта формулировка совета пригодится на первом сборном проекте, только тсс, между нами)
# </div>

# %%
#  Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра

price_sq_meters_max = data.pivot_table(index = 'locality_name', values = 'price_sq_meters', aggfunc = 'max')


print('Населённый пункт с самой высокой стоимостью квадратного метра')
print(price_sq_meters_max.query('price_sq_meters == price_sq_meters.max()'))
print('')
print('')

price_sq_meters_min = data.pivot_table(index = 'locality_name', values = 'price_sq_meters', aggfunc = 'min')

print('Населённый пункт с самой низкой стоимостью квадратного метра')
print(price_sq_meters_min.query('price_sq_meters == price_sq_meters.min()'))
# Out:
# Населённый пункт с самой высокой стоимостью квадратного метра
#                  price_sq_meters
# locality_name
# Санкт-Петербург           848484
#
#
# Населённый пункт с самой низкой стоимостью квадратного метра
#                price_sq_meters
# locality_name
# посёлок Свирь             7962

# %% [markdown]
# #### Исследовательский анализ данных.  Выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. Опишем, как стоимость объектов зависит от расстояния до центра города.

# %%
# Получим срез по квартирам в Санкт-Петербурге. 

# Найдем максимальное расстояние, на котором расположена квартира в Санкт-Петербурге от центра. 
data_SPB = data.query('locality_name == "Санкт-Петербург"')
distance_max = data_SPB['cityCenters_km'].max()
print(distance_max)
# Out:
# 29

# %%
# Создадим новый столбец, в котором категоризируем данные по каждому километру.

def distance_group(distance):
    for data in range(30):
        if distance <= data:
            return data

data_SPB['distance_group'] = data_SPB['cityCenters_km'].apply(distance_group)
#print(data_SPB)

# Сгруппируем данные по каждому километру и с помощью сводной таблицы рассчитаем среднее значение стоимости кв. метра.
data_SPB_grouped = data_SPB.pivot_table(index = 'distance_group', values = 'price_sq_meters', aggfunc = 'median')
data_SPB_grouped.columns = ['median_price_sq_meters']
data_SPB_grouped['median_price_sq_meters'] = data_SPB_grouped['median_price_sq_meters'].astype(int)
print(data_SPB_grouped) 
# визуализируем зависимость с помощью графика

data_SPB_grouped.plot(y = 'median_price_sq_meters', style='o-',figsize=(10, 5), title = 'Cтоимость объектов в зависимости от расстояния до центра города')
plt.show()
# Out:
#                 median_price_sq_meters
# distance_group
# 0                               125565
# 1                               122988
# 2                               112820
# 3                               109750
# 4                               124556
# 5                               123571
# 6                               128846
# 7                               122222
# 8                               114487
# 9                               104910
# 10                              103787
# 11                              103125
# 12                              104444
# 13                              103911
# 14                              103132
# 15                               98387
# 16                               97959
# 17                               92063
# 18                               94017
# 19                               95138
# 20                              107021
# 21                               88219
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. В твой код добавил заголовок, посмотри, пожалуйста, этот момент. Очень важно оформлять графики
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# 1. Была проведена предобработка базы данных объявлений за несколько лет о продаже квартир в Санкт-Петербурге и в соседних населённых пунктах.
#
#
# 2. Был проведен исследовательский анализ базы данных, изучены параметры объектов и выявлены типичные объекты, выставленные на продажу.
#
#
# 3. Большинство квартир продается в период от 1,5 до 6 месяцев  с момента размещения объявления.Очень быстрыми можно считать продажи в течение менее 45 дней. Очень медленными продажами можно считать продажи дольше 380 дней.
#
#
# 4. Средняя стоимость (руб.) квадрадного метра в 10 населённых пунктах с наибольшим числом объявлений:
#
# - Санкт-Петербург                     103921
# - посёлок Кудрово                      96296
# - посёлок Парголово                    92282
# - посёлок Мурино                       86268
# - посёлок Шушары                       77540
# - Сертолово                            67720
# - Гатчина                              67045
# - Всеволожск                           66072
# - Выборг                               58133
# - Кириши                               37976
#
#
#  -  Максимальная стоимость квадрадного метра была выявлена также в Санкт-Петербурге и составила 848 484 руб/м2
#  -  Минимальная стоимость квадрадного метра в посёлке Свирь 7 962 руб/м2
#
# 5. Стоимость объектов в Санкт-Петербурге имеет прямую зависимость от расстояния до центра города. Чем ближе к центру, тем  выше средняя стоимость за м2.
#
#
# 6. Выявлено влияние параметров квартиры на её стоимость.
# - Наибольшее влияние на стоимость квартиры оказывают такие параметры, как
# * населенный пункт.
# * удаленность от центра населенного пункта
# * общая площадь
# * количество комнат
# * этаж «первый», «последний», или «промежуточный»
# * год продажи (публикации объявления)
#
# - В меньшей степени влияют такие показатели, как:
# * жилая площадь
# * площадь кухни
# * высота потолков
# * день, месяц публикации
#
# - Практически не влияют на стоимость:
# * удаленность от аэропортов
# * наличие прудов и парков

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Выгрузка данных
#
# 2) Удаление данных
#
# 3) Округление
#
# 4) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]   файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]   определены пропущенные значения
# - [x]   заполнены пропущенные значения там, где это возможно
# - [x]   есть пояснение, какие пропущенные значения обнаружены
# - [x]   изменены типы данных
# - [x]   есть пояснение, в каких столбцах изменены типы и почему
# - [x]   устранены неявные дубликаты в названиях населённых пунктов
# - [x]   устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x] изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
